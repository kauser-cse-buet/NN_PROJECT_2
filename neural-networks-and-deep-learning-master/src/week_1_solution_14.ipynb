# %%
import mnist_loader
import numpy as np 
import pandas as pd 

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
print("Training data, validation data and test data loaded.")
# Out:
# Training data, validation data and test data loaded.

# %%
print("14. Reapet 12 for a deep network with three hidden layers, with 30 neuron in each.")
# Out:
# 14. Reapet 12 for a deep network with three hidden layers, with 30 neuron in each.

# %%
import network2
net2_all_train = network2.Network([784, 30, 30, 30, 10], cost=network2.CrossEntropyCost)
net2_all_train.large_weight_initializer()

epochs = 400

evaluation_cost_all_train, evaluation_accuracy_all_train, training_cost_all_train, training_accuracy_all_train = net2_all_train.SGD(
    training_data, 
    epochs, 
    10, 
    0.5, 
    evaluation_data=test_data,
    lmbda=5.0,
    monitor_evaluation_cost=True,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=True,
    monitor_training_accuracy=True
)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.35470700202
# Accuracy on training data: 45885 / 50000
# Cost on evaluation data: 4.7731181301
# Accuracy on evaluation data: 9161 / 10000
#
# Epoch 1 training complete
# Cost on training data: 0.977238185234
# Accuracy on training data: 46808 / 50000
# Cost on evaluation data: 3.3413493973
# Accuracy on evaluation data: 9298 / 10000
#
# Epoch 2 training complete
# Cost on training data: 0.783991961857
# Accuracy on training data: 47070 / 50000
# Cost on evaluation data: 2.48929308517
# Accuracy on evaluation data: 9393 / 10000
#
# Epoch 3 training complete
# Cost on training data: 0.661731907293
# Accuracy on training data: 47062 / 50000
# Cost on evaluation data: 1.99874702098
# Accuracy on evaluation data: 9350 / 10000
#
# Epoch 4 training complete
# Cost on training data: 0.539353112243
# Accuracy on training data: 47832 / 50000
# Cost on evaluation data: 1.66086387002
# Accuracy on evaluation data: 9504 / 10000
#
# ...
