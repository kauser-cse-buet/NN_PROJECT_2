# %%
import mnist_loader
import numpy as np 
import pandas as pd 

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
print("Training data, validation data and test data loaded.")
# Out:
# Training data, validation data and test data loaded.

# %%
import network2
network2 = reload(network2)

net2_all_train = network2.Network([784,30, 30, 30, 10], cost=network2.CrossEntropyCost, activation_fn=network2.LecunTanhActivation)
net2_all_train.large_weight_initializer()

evaluation_cost_all_train, evaluation_accuracy_all_train, training_cost_all_train, training_accuracy_all_train = net2_all_train.SGD(  
    training_data=training_data, 
    epochs=30, 
    mini_batch_size=10, 
    eta=0.1,
    evaluation_data=test_data,
    lmbda=5.0,
    monitor_evaluation_cost=True,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=True,
    monitor_training_accuracy=True
)
# Out:
# Epoch 0 training complete
# network2.py:54: RuntimeWarning: invalid value encountered in log
#   return np.sum(np.nan_to_num(-y*np.log(a)-(1-y)*np.log(1-a)))
# Cost on training data: 4.53109387615
# Accuracy on training data: 4994 / 50000
# Cost on evaluation data: 9.54895689622
# Accuracy on evaluation data: 994 / 10000
#
# Epoch 1 training complete
# Cost on training data: 4.52436929357
# Accuracy on training data: 5544 / 50000
# Cost on evaluation data: 9.53978157116
# Accuracy on evaluation data: 1098 / 10000
#
# Epoch 2 training complete
# Cost on training data: 4.54023431219
# Accuracy on training data: 4950 / 50000
# Cost on evaluation data: 9.54978416011
# Accuracy on evaluation data: 955 / 10000
#
# Epoch 3 training complete
# Cost on training data: 4.52615776709
# Accuracy on training data: 4498 / 50000
# Cost on evaluation data: 9.53153821019
# Accuracy on evaluation data: 888 / 10000
#
# Epoch 4 training complete
# Cost on training data: 4.50849038255
# Accuracy on training data: 5674 / 50000
# Cost on evaluation data: 9.50711315026
# Accuracy on evaluation data: 1130 / 10000
#
# Epoch 5 training complete
# Cost on training data: 4.52425798133
# Accuracy on training data: 4873 / 50000
# Cost on evaluation data: 9.51959838075
# Accuracy on evaluation data: 981 / 10000
#
# Epoch 6 training complete
# Cost on training data: 4.5483263722
# Accuracy on training data: 4882 / 50000
# Cost on evaluation data: 9.53351446954
# Accuracy on evaluation data: 978 / 10000
#
# Epoch 7 training complete
# Cost on training data: 4.50542935316
# Accuracy on training data: 5107 / 50000
# Cost on evaluation data: 9.49077398305
# Accuracy on evaluation data: 1007 / 10000
#
# Epoch 8 training complete
# Cost on training data: 4.52731647504
# Accuracy on training data: 4957 / 50000
# Cost on evaluation data: 9.50556588373
# Accuracy on evaluation data: 1028 / 10000
#
# Epoch 9 training complete
# Cost on training data: 4.5142978293
# Accuracy on training data: 5686 / 50000
# Cost on evaluation data: 9.49073145488
# Accuracy on evaluation data: 1134 / 10000
#
# Epoch 10 training complete
# Cost on training data: 4.50949135888
# Accuracy on training data: 5112 / 50000
# Cost on evaluation data: 9.48039415212
# Accuracy on evaluation data: 1007 / 10000
#
# Epoch 11 training complete
# Cost on training data: 4.53437395841
# Accuracy on training data: 5003 / 50000
# Cost on evaluation data: 9.50002908998
# Accuracy on evaluation data: 1010 / 10000
#
# Epoch 12 training complete
# Cost on training data: 4.50770866808
# Accuracy on training data: 5138 / 50000
# Cost on evaluation data: 9.4667865756
# Accuracy on evaluation data: 1010 / 10000
#
# Epoch 13 training complete
# Cost on training data: 4.53859135308
# Accuracy on training data: 4948 / 50000
# Cost on evaluation data: 9.49501476534
# Accuracy on evaluation data: 953 / 10000
#
# Epoch 14 training complete
# Cost on training data: 4.50223932584
# Accuracy on training data: 5053 / 50000
# Cost on evaluation data: 9.45338656901
# Accuracy on evaluation data: 996 / 10000
#
# Epoch 15 training complete
# Cost on training data: 4.50230164035
# Accuracy on training data: 5012 / 50000
# Cost on evaluation data: 9.44582391091
# Accuracy on evaluation data: 1016 / 10000
#
# Epoch 16 training complete
# Cost on training data: 4.50690099208
# Accuracy on training data: 5024 / 50000
# Cost on evaluation data: 9.446680848
# Accuracy on evaluation data: 1018 / 10000
#
# Epoch 17 training complete
# Cost on training data: 4.49969876291
# Accuracy on training data: 5157 / 50000
# Cost on evaluation data: 9.43444931986
# Accuracy on evaluation data: 1029 / 10000
#
# Epoch 18 training complete
# Cost on training data: 4.50220359041
# Accuracy on training data: 5615 / 50000
# Cost on evaluation data: 9.43274747267
# Accuracy on evaluation data: 1119 / 10000
#
# Epoch 19 training complete
# Cost on training data: 4.52254007526
# Accuracy on training data: 4506 / 50000
# Cost on evaluation data: 9.44504293389
# Accuracy on evaluation data: 887 / 10000
#
# Epoch 20 training complete
# Cost on training data: 4.54724453725
# Accuracy on training data: 5685 / 50000
# Cost on evaluation data: 9.46726527267
# Accuracy on evaluation data: 1137 / 10000
#
# Epoch 21 training complete
# Cost on training data: 4.49668046461
# Accuracy on training data: 5118 / 50000
# Cost on evaluation data: 9.41149661282
# Accuracy on evaluation data: 1012 / 10000
#
# Epoch 22 training complete
# Cost on training data: 4.51096364497
# Accuracy on training data: 4953 / 50000
# Cost on evaluation data: 9.42235034072
# Accuracy on evaluation data: 952 / 10000
#
# Epoch 23 training complete
# Cost on training data: 4.50564948802
# Accuracy on training data: 5681 / 50000
# Cost on evaluation data: 9.41079879545
# Accuracy on evaluation data: 1134 / 10000
#
# Epoch 24 training complete
# Cost on training data: 4.50194673302
# Accuracy on training data: 4871 / 50000
# Cost on evaluation data: 9.40200802589
# Accuracy on evaluation data: 981 / 10000
#
# Epoch 25 training complete
# Cost on training data: 4.49428005185
# Accuracy on training data: 4996 / 50000
# Cost on evaluation data: 9.3880116727
# Accuracy on evaluation data: 1012 / 10000
#
# Epoch 26 training complete
# Cost on training data: 4.48723922149
# Accuracy on training data: 5111 / 50000
# Cost on evaluation data: 9.37798445163
# Accuracy on evaluation data: 1009 / 10000
#
# Epoch 27 training complete
# Cost on training data: 4.49391066246
# Accuracy on training data: 5127 / 50000
# Cost on evaluation data: 9.37943029207
# Accuracy on evaluation data: 1010 / 10000
#
# Epoch 28 training complete
# Cost on training data: 4.50030944911
# Accuracy on training data: 5684 / 50000
# Cost on evaluation data: 9.38121821672
# Accuracy on evaluation data: 1137 / 10000
#
# Epoch 29 training complete
# Cost on training data: 4.49152238525
# Accuracy on training data: 5159 / 50000
# Cost on evaluation data: 9.36520232491
# Accuracy on evaluation data: 1029 / 10000
