# %%
import mnist_loader
import numpy as np 
import pandas as pd 

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
print("Training data, validation data and test data loaded.")
# Out:
# Training data, validation data and test data loaded.

# %%
import network2
network2 = reload(network2)

net2_all_train = network2.Network([784,100, 10], cost=network2.CrossEntropyCost, activation_fn=network2.LecunTanhActivation)
net2_all_train.large_weight_initializer()

evaluation_cost_all_train, evaluation_accuracy_all_train, training_cost_all_train, training_accuracy_all_train = net2_all_train.SGD(  
    training_data=training_data, 
    epochs=30, 
    mini_batch_size=10, 
    eta=0.1,
    evaluation_data=test_data,
    lmbda=5.0,
    monitor_evaluation_cost=True,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=True,
    monitor_training_accuracy=True
)
# Out:
# Epoch 0 training complete
# Cost on training data: 6.63165139396
# Accuracy on training data: 9923 / 50000
# Cost on evaluation data: 22.3583003355
# Accuracy on evaluation data: 2039 / 10000
#
# Epoch 1 training complete
# Cost on training data: 6.45612247655
# Accuracy on training data: 21066 / 50000
# Cost on evaluation data: 22.1054032515
# Accuracy on evaluation data: 4230 / 10000
#
# Epoch 2 training complete
# Cost on training data: 6.27724645017
# Accuracy on training data: 26901 / 50000
# Cost on evaluation data: 21.8929442316
# Accuracy on evaluation data: 5452 / 10000
#
# Epoch 3 training complete
# Cost on training data: 6.02980483535
# Accuracy on training data: 28710 / 50000
# Cost on evaluation data: 21.6318920754
# Accuracy on evaluation data: 5867 / 10000
#
# Epoch 4 training complete
# Cost on training data: 5.96886024839
# Accuracy on training data: 30063 / 50000
# Cost on evaluation data: 21.5347605154
# Accuracy on evaluation data: 6161 / 10000
#
# Epoch 5 training complete
# Cost on training data: 5.94963263032
# Accuracy on training data: 30535 / 50000
# Cost on evaluation data: 21.5010385063
# Accuracy on evaluation data: 6210 / 10000
#
# Epoch 6 training complete
# Cost on training data: 5.91670491747
# Accuracy on training data: 30830 / 50000
# Cost on evaluation data: 21.4526258083
# Accuracy on evaluation data: 6256 / 10000
#
# Epoch 7 training complete
# Cost on training data: 5.92750733355
# Accuracy on training data: 30519 / 50000
# Cost on evaluation data: 21.44755123
# Accuracy on evaluation data: 6194 / 10000
#
# Epoch 8 training complete
# Cost on training data: 5.88457991734
# Accuracy on training data: 31575 / 50000
# Cost on evaluation data: 21.38505918
# Accuracy on evaluation data: 6416 / 10000
#
# Epoch 9 training complete
# Cost on training data: 5.88443540461
# Accuracy on training data: 31413 / 50000
# Cost on evaluation data: 21.3735175372
# Accuracy on evaluation data: 6397 / 10000
#
# Epoch 10 training complete
# Cost on training data: 5.87194256872
# Accuracy on training data: 31588 / 50000
# Cost on evaluation data: 21.34536678
# Accuracy on evaluation data: 6402 / 10000
#
# Epoch 11 training complete
# Cost on training data: 5.84637615079
# Accuracy on training data: 31675 / 50000
# Cost on evaluation data: 21.3060992928
# Accuracy on evaluation data: 6449 / 10000
#
# Epoch 12 training complete
# Cost on training data: 5.85138621806
# Accuracy on training data: 31842 / 50000
# Cost on evaluation data: 21.2944078737
# Accuracy on evaluation data: 6437 / 10000
#
# Epoch 13 training complete
# Cost on training data: 5.83857903738
# Accuracy on training data: 31433 / 50000
# Cost on evaluation data: 21.2619868704
# Accuracy on evaluation data: 6347 / 10000
#
# Epoch 14 training complete
# Cost on training data: 5.79588469432
# Accuracy on training data: 32460 / 50000
# Cost on evaluation data: 21.2066845654
# Accuracy on evaluation data: 6561 / 10000
#
# Epoch 15 training complete
# Cost on training data: 5.80894286573
# Accuracy on training data: 32387 / 50000
# Cost on evaluation data: 21.2034269068
# Accuracy on evaluation data: 6544 / 10000
#
# Epoch 16 training complete
# Cost on training data: 5.82159845633
# Accuracy on training data: 32427 / 50000
# Cost on evaluation data: 21.1958761711
# Accuracy on evaluation data: 6595 / 10000
#
# Epoch 17 training complete
# Cost on training data: 5.79351864939
# Accuracy on training data: 32001 / 50000
# Cost on evaluation data: 21.1579283818
# Accuracy on evaluation data: 6493 / 10000
#
# Epoch 18 training complete
# Cost on training data: 5.78635767912
# Accuracy on training data: 32736 / 50000
# Cost on evaluation data: 21.131942793
# Accuracy on evaluation data: 6606 / 10000
#
# Epoch 19 training complete
# Cost on training data: 5.77921999938
# Accuracy on training data: 32714 / 50000
# Cost on evaluation data: 21.1083342222
# Accuracy on evaluation data: 6650 / 10000
#
# Epoch 20 training complete
# Cost on training data: 5.77994160001
# Accuracy on training data: 31759 / 50000
# Cost on evaluation data: 21.0963550386
# Accuracy on evaluation data: 6421 / 10000
#
# Epoch 21 training complete
# Cost on training data: 5.7669109031
# Accuracy on training data: 32296 / 50000
# Cost on evaluation data: 21.0687134656
# Accuracy on evaluation data: 6565 / 10000
#
# Epoch 22 training complete
# Cost on training data: 5.75269385859
# Accuracy on training data: 32787 / 50000
# Cost on evaluation data: 21.0300554429
# Accuracy on evaluation data: 6641 / 10000
#
# Epoch 23 training complete
# Cost on training data: 5.74923376645
# Accuracy on training data: 32581 / 50000
# Cost on evaluation data: 21.0184879287
# Accuracy on evaluation data: 6627 / 10000
#
# Epoch 24 training complete
# Cost on training data: 5.72762736504
# Accuracy on training data: 32946 / 50000
# Cost on evaluation data: 20.9777159717
# Accuracy on evaluation data: 6670 / 10000
#
# Epoch 25 training complete
# Cost on training data: 5.73291501993
# Accuracy on training data: 33162 / 50000
# Cost on evaluation data: 20.968179783
# Accuracy on evaluation data: 6730 / 10000
#
# Epoch 26 training complete
# Cost on training data: 5.71902818053
# Accuracy on training data: 33320 / 50000
# Cost on evaluation data: 20.9321454276
# Accuracy on evaluation data: 6758 / 10000
#
# Epoch 27 training complete
# Cost on training data: 5.71129017686
# Accuracy on training data: 32842 / 50000
# Cost on evaluation data: 20.9118413991
# Accuracy on evaluation data: 6666 / 10000
#
# Epoch 28 training complete
# Cost on training data: 5.69719965547
# Accuracy on training data: 33553 / 50000
# Cost on evaluation data: 20.8879453753
# Accuracy on evaluation data: 6816 / 10000
#
# Epoch 29 training complete
# Cost on training data: 5.69775962637
# Accuracy on training data: 33066 / 50000
# Cost on evaluation data: 20.8707464996
# Accuracy on evaluation data: 6713 / 10000
